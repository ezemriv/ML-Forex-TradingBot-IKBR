# %% [markdown]
# ## Imports

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from scipy.stats import skew, kurtosis
from datetime import datetime

from FinancialInstrumentAnalyzer import *

# %% [markdown]
# ## Compare Stocks

# %%
tickers = ['AAPL', 'TSLA', 'GOOGL']
start = '2018-01-01'
end = end = datetime.today().strftime('%Y-%m-%d')  # Get today's date in YYYY-MM-DD format

analyzer = FinancialInstrumentAnalyzer(tickers, start, end, threshold=0.025)
analyzer.analyze()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Statistical Summary:
#        mean_daily_log_return  daily_volatility  annualized_log_return  \
# AAPL                0.001022          0.019512               0.257550
# TSLA                0.001427          0.039739               0.359569
# GOOGL               0.000661          0.019483               0.166582
#
#        annualized_volatility  annualized_return  skewness  kurtosis  \
# AAPL                0.309751           0.293756 -0.209577  5.129709
# TSLA                0.630842           0.432712 -0.138295  3.531412
# GOOGL               0.309278           0.181261 -0.250657  4.039292
#
#        adf_statistic    adf_pvalue
# AAPL      -12.886763  4.536787e-24
# TSLA      -41.980419  0.000000e+00
# GOOGL     -13.749653  1.056405e-25
#
# ...

# %% [markdown]
# ## Compare Forex Pairs

# %%
tickers = ['EURUSD=X', 'GBPUSD=X', 'USDJPY=X'] 
analyzer = FinancialInstrumentAnalyzer(tickers, start, end, threshold=0.01)
analyzer.analyze()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Statistical Summary:
#           mean_daily_log_return  daily_volatility  annualized_log_return  \
# EURUSD=X              -0.000042          0.004453              -0.010466
# GBPUSD=X              -0.000010          0.005647              -0.002513
# USDJPY=X               0.000135          0.005316               0.034130
#
#           annualized_volatility  annualized_return  skewness  kurtosis  \
# EURUSD=X               0.070696          -0.010412 -0.135580  1.951789
# GBPUSD=X               0.089644          -0.002510 -0.231839  5.147784
# USDJPY=X               0.084382           0.034720 -0.459736  4.489779
#
#           adf_statistic    adf_pvalue
# EURUSD=X     -18.724393  2.032038e-30
# GBPUSD=X     -40.556881  0.000000e+00
# USDJPY=X     -41.294617  0.000000e+00
#
# ...
